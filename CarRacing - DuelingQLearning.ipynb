# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import gym
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython.display import HTML, clear_output, Image
# %matplotlib inline

from utils import show_video, dynamic_gpu_usage, play_in_video, evaluate, moving_average
from wrappers import ActionMapWrapper, BWrapper, MaxStepsWrapper, StackedLagWrapper, FrameSkipper
from QLearningAgent import QLearningAgent

dynamic_gpu_usage()
# Out:
# Tensorflow version: 1.14.0
# 1 Physical GPUs, 1 Logical GPUs

# %%
env_name = 'CarRacing-v0'
recordings = 'recordings/carracing-qlearning1'
env = MaxStepsWrapper(FrameSkipper(gym.make(env_name, verbose=False), 50, [0,0,0]), 10000)

play_in_video(env, recordings + "/0")
# Out:
# Total reward: -35.972222222222825
# <video alt="test"
#                     controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
IMAGE_SIZE = (64, 64)

action_map = [
    [0,0,0], # Nothing
    [0,1,0], # Full gas
    [0,0,1], # Full break
    [-1,0,0], # Full left
    [1,0,0], # Full right
]  

train_env = StackedLagWrapper(BWrapper(ActionMapWrapper(FrameSkipper(gym.make(env_name, verbose=False), 50, [0,0,0]), action_map), IMAGE_SIZE), lag=4)

obs_shape = train_env.reset().shape
n_actions = len(action_map)

for _ in range(50):
    obs, _, _, _ = train_env.step(0)

plt.imshow(np.hstack([x for x in obs.transpose([2,0,1])]));

# %%
from tensorflow.keras import models, layers, backend, optimizers, utils

def dueling_network():
    input_layer = layers.Input(obs_shape)
    cnn1 = layers.Conv2D(filters=16, kernel_size=(3,3), strides=(2,2), activation='elu')(input_layer)
    cnn2 = layers.Conv2D(filters=32, kernel_size=(3,3), strides=(2,2), activation='elu')(cnn1)
    cnn3 = layers.Conv2D(filters=64, kernel_size=(3,3), strides=(2,2), activation='elu')(cnn2)
    flat = layers.Flatten()(cnn3)
    hidden = layers.Dense(128, activation='elu', name='hidden')(flat)
    advantage = layers.Dense(n_actions, name='advantage')(hidden)
    minimum_adv = -backend.min(advantage, axis=1, keepdims=True)
    value = layers.Dense(1, name='value')(hidden)
    add = layers.Add(name='qvalues')([value, advantage, minimum_adv])
    model = models.Model(inputs=input_layer, outputs=add)
    return model

q_model = dueling_network()
utils.plot_model(q_model, show_shapes=True)

agent = QLearningAgent(obs_shape, n_actions, model=q_model, use_target_network=True, learning_rate=0.001)

play_in_video(train_env, recordings + "/1", agent)
Image("model.png")
# Out:
# WARNING:tensorflow:From /home/jaume/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/jaume/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/jaume/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/jaume/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Total reward: -94.99999999999886
# <video alt="test"
#                     controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
n_sessions = 1000000
n_minibaches = 1
# max_steps = 1000
exploration_rate = 0.5

memory = []
er_history = []
reward_history = []
loss_history = []
test_reward_history = [0]
session_steps_history = []

# %%
builder = lambda: StackedLagWrapper(BWrapper(ActionMapWrapper(FrameSkipper(gym.make(env_name, verbose=False), 50, [0,0,0]), action_map), IMAGE_SIZE), lag=4)
eval_env = builder()

er_history.append(exploration_rate)

s = train_env.reset()

for i in tqdm(range(n_sessions), total=n_sessions, desc="Sessions"):
    for _ in range(10):
        action = agent.next_action(s, exploration_rate)
        s_new, r, done, _ = train_env.step(action)
        memory.append([s, action, r, s_new, done])
        s = s_new
        if done:
            s = train_env.reset()
    
    memory = memory[-100000:]
    loss = agent.train_on_batch(*list(map(np.array, zip(*random.sample(memory, min(len(memory), 64))))))
    loss_history.append(np.mean(loss))
    
    
    if i%500 == 0:
        agent.update_target_network()
        exploration_rate = max(exploration_rate*0.99, 0.01)
        test_reward_history.append(evaluate(eval_env, agent, times=3, exploration_rate=exploration_rate))
        er_history.append(exploration_rate)
        

    if i%250 == 0:
        print("Iteration:", i)
        clear_output()
        plt.figure(figsize=(10,4))
        plt.plot(test_reward_history)
        plt.title("Evaluation reward")
        plt.ylabel("Score")
        plt.xlabel("Session")
        plt.show()

        plt.figure(figsize=(10,4))
        plt.plot(er_history)
        plt.title("Exploration rate")
        plt.ylabel("Value")
        plt.xlabel("Session")
        plt.show()
        
        plt.figure(figsize=(10,4))
        plt.plot(moving_average(loss_history, span=100, min_periods=100))
        plt.title("Loss history")
        plt.ylabel("Value")
        plt.xlabel("Session")
        plt.show()

    if np.mean(test_reward_history[-10:]) > 200:
        break

# %%
play_in_video(train_env, recordings + "/2", agent)
# Out:
# Total reward: 242.83783783782613
# <video alt="test"
#                     controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
play_in_video(builder(), recordings + "/2", agent)
# Out:
# Total reward: 413.6505190311363
# <video alt="test"
#                     controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
